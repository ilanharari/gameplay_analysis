# %% [markdown]
# ## Predictive Modeling

# %% [markdown]
# ### Model Construction

# %% [markdown]
# - Model Selection
# - Training & Validation Dataset formation
# - Hyperparameter Selection & Tuning
# - Model Estimation
# - Model Fitting

# %% [markdown]
# #### Model Selection

# %% [markdown]
# #### Training & Validation Dataset Formation

# %% [markdown]
# #### Hyperparameter Selection & Tuning

# %% [markdown]
# #### Model Estimation

# %% [markdown]
# #### Model Fitting

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# - Model Scoring

# %% [markdown]
# #### Model Scoring
